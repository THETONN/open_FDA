# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Drug V1

# %%
drug_v1 = pd.read_csv('../../data/v1/drug_clean_search.csv')
drug_v1.head()
# Out:
#             medicinal_product medicinal_product_clean
# 0                  FLECAINIDE              flecainide
# 1                 PROPRANOLOL             propranolol
# 2                     ESMOLOL                 esmolol
# 3       SOTALOL HYDROCHLORIDE                 sotalol
# 4  PROCAINAMIDE HYDROCHLORIDE            procainamide

# %%
drug_v1.isna().sum()
# Out:
# medicinal_product          0
# medicinal_product_clean    3
# dtype: int64

# %%
drug_v1[drug_v1['medicinal_product'] == '.']
# Out:
#      medicinal_product medicinal_product_clean
# 8151                 .                       .

# %%
drug_v1[drug_v1['medicinal_product_clean'].isna()]
# Out:
#                           medicinal_product medicinal_product_clean
# 11474  PRIVATE LABEL STRENGTH UNKNOWN (NCH)                     NaN
# 11476                               URBANIL                     NaN
# 11477                             VALPAKINE                     NaN

# %%
drug_v1 = drug_v1.dropna(subset=['medicinal_product_clean'])
drug_v1 = drug_v1[drug_v1['medicinal_product'] != '.']

print(drug_v1.isna().sum())
# Out:
# medicinal_product          0
# medicinal_product_clean    0
# dtype: int64

# %%
unique_drug_v1   = drug_v1['medicinal_product'].nunique()
unique_clean_drug_v1 = drug_v1['medicinal_product_clean'].nunique()

print(f'Unique Raw drug V1: {unique_drug_v1:,}')
print(f'Unique Clean drug V1: {unique_clean_drug_v1:,}')
# Out:
# Unique Raw drug V1: 16,532
# Unique Clean drug V1: 6,644

# %% [markdown]
# ### clean drug

# %%
clean_drug_v1 = pd.read_csv('../../data/v1/clean_drug.csv')
clean_drug_v1
# Out:
#        safetyreportid      medicinal_product medicinal_product_clean
# 0            25129349             FLECAINIDE              flecainide
# 1            25129349            PROPRANOLOL             propranolol
# 2            25129367                ESMOLOL                 esmolol
# 3            25129367  SOTALOL HYDROCHLORIDE                 sotalol
# 4            25129367            PROPRANOLOL             propranolol
# ...               ...                    ...                     ...
# 881391        8651696                EXTAVIA                 extavia
# 881392        8651696                EXTAVIA                 extavia
# 881393        8651696                EXTAVIA                 extavia
# 881394        8651812            ANTIBIOTICS             antibiotics
# 881395        8651812               REMICADE              infliximab
#
# [881396 rows x 3 columns]

# %%
clean_drug_v1.isna().sum()
# Out:
# safetyreportid              0
# medicinal_product           0
# medicinal_product_clean    39
# dtype: int64

# %%
clean_drug_v1[clean_drug_v1['medicinal_product_clean'] == '.']
# Out:
#        safetyreportid medicinal_product medicinal_product_clean
# 305402      5635836-2                 .                       .
# 305403      5635836-2                 .                       .
# 305404      5635836-2                 .                       .
# 305405      5635836-2                 .                       .
# 305406      5635836-2                 .                       .
# 305407      5635836-2                 .                       .

# %%
clean_drug_v1[clean_drug_v1['medicinal_product_clean'].isna()]
# Out:
#        safetyreportid                     medicinal_product  \
# 483588      6543176-2  PRIVATE LABEL STRENGTH UNKNOWN (NCH)
# 483589      6543176-2  PRIVATE LABEL STRENGTH UNKNOWN (NCH)
# 483590      6543176-2  PRIVATE LABEL STRENGTH UNKNOWN (NCH)
# 483591      6543176-2  PRIVATE LABEL STRENGTH UNKNOWN (NCH)
# 483987      6543549-8                               URBANIL
# 483988      6543549-8                               URBANIL
# 483989      6543549-8                               URBANIL
# 483990      6543549-8                             VALPAKINE
# 483991      6543549-8                             VALPAKINE
# 483992      6543549-8                             VALPAKINE
# 484026      6543741-2                             VALPAKINE
# 484027      6543741-2                             VALPAKINE
# 486018      6552416-5                             VALPAKINE
# 486019      6552416-5                             VALPAKINE
# 486020      6552416-5                             VALPAKINE
# 497944      6612835-5                             VALPAKINE
# 497945      6612835-5                             VALPAKINE
# 497946      6612835-5                             VALPAKINE
# 524820      6742860-5                             VALPAKINE
# 524821      6742860-5                             VALPAKINE
# 524822      6742860-5                             VALPAKINE
# 524823      6742860-5                             VALPAKINE
# 524824      6742860-5                             VALPAKINE
# 524825      6742860-5                             VALPAKINE
# 528099      6754724-1                             VALPAKINE
# 528100      6754724-1                             VALPAKINE
# 528101      6754724-1                             VALPAKINE
# 537724      6813580-3                             VALPAKINE
# 537725      6813580-3                             VALPAKINE
# 537726      6813580-3                             VALPAKINE
# 537727      6813580-3                             VALPAKINE
# 537728      6813580-3                             VALPAKINE
# 537729      6813580-3                             VALPAKINE
# 538232      6815607-1                             VALPAKINE
# 538233      6815607-1                             VALPAKINE
# 563470      7012991-3                             VALPAKINE
# 563471      7012991-3                             VALPAKINE
# 563472      7012991-3                             VALPAKINE
# 563473      7012991-3                             VALPAKINE
#
#        medicinal_product_clean
# 483588                     NaN
# 483589                     NaN
# 483590                     NaN
# 483591                     NaN
# 483987                     NaN
# 483988                     NaN
# 483989                     NaN
# 483990                     NaN
# 483991                     NaN
# 483992                     NaN
# 484026                     NaN
# 484027                     NaN
# 486018                     NaN
# 486019                     NaN
# 486020                     NaN
# 497944                     NaN
# 497945                     NaN
# 497946                     NaN
# 524820                     NaN
# 524821                     NaN
# 524822                     NaN
# 524823                     NaN
# 524824                     NaN
# 524825                     NaN
# 528099                     NaN
# 528100                     NaN
# 528101                     NaN
# 537724                     NaN
# 537725                     NaN
# 537726                     NaN
# 537727                     NaN
# 537728                     NaN
# 537729                     NaN
# 538232                     NaN
# 538233                     NaN
# 563470                     NaN
# 563471                     NaN
# 563472                     NaN
# 563473                     NaN

# %% [markdown]
# ### ped with clean drug

# %%
ped_data_new = pd.read_csv('../../data/v1/ped_data_new.csv.gz', compression='gzip')

ped_data_new.head()
# Out:
#    patient_custom_master_age patient_custom_master_age_unit  patient_onsetage  \
# 0                   0.500000                           Year               6.0
# 1                   0.500000                           Year               6.0
# 2                   0.013699                           Year               5.0
# 3                   0.013699                           Year               5.0
# 4                   0.013699                           Year               5.0
#
#   patient_onsetageunit patient_sex safetyreportid          nichd  \
# 0                Month      Female       25129349        infancy
# 1                Month      Female       25129349        infancy
# 2                  Day     Unknown       25129367  term_neonatal
# 3                  Day     Unknown       25129367  term_neonatal
# 4                  Day     Unknown       25129367  term_neonatal
#
#                 ich_ema       fda lastupdate_date  ...  \
# 0  infants_and_toddlers   infants      2025-04-09  ...
# 1  infants_and_toddlers   infants      2025-04-09  ...
# 2  term_newborn_infants  neonates      2025-04-09  ...
# 3  term_newborn_infants  neonates      2025-04-09  ...
# 4  term_newborn_infants  neonates      2025-04-09  ...
#
#                    reporter_company reporter_country  \
# 0                  ES-AEMPS-1647130               ES
# 1                  ES-AEMPS-1647130               ES
# 2  US-AUROBINDO-AUR-APL-2025-015649               US
# 3  US-AUROBINDO-AUR-APL-2025-015649               US
# 4  US-AUROBINDO-AUR-APL-2025-015649               US
#
#       reporter_qualification  drug_administration  \
# 0                  Physician                 Oral
# 1                  Physician                 Oral
# 2  Other health professional              Unknown
# 3  Other health professional              Unknown
# 4  Other health professional              Unknown
#
#                                drug_characterization  \
# 0  Suspect (the drug was considered by the report...
# 1  Concomitant (the drug was reported as being ta...
# 2  Suspect (the drug was considered by the report...
# 3  Suspect (the drug was considered by the report...
# 4  Suspect (the drug was considered by the report...
#
#                 drug_indication      medicinal_product  \
# 0  Supraventricular tachycardia             FLECAINIDE
# 1  Supraventricular tachycardia            PROPRANOLOL
# 2  Supraventricular tachycardia                ESMOLOL
# 3  Supraventricular tachycardia  SOTALOL HYDROCHLORIDE
# 4  Supraventricular tachycardia            PROPRANOLOL
#
#            reaction_meddrapt    reaction_outcome medicinal_product_clean
# 0  Bundle branch block right  Recovered/resolved              flecainide
# 1  Bundle branch block right  Recovered/resolved             propranolol
# 2          Treatment failure             Unknown                 esmolol
# 3          Treatment failure             Unknown                 sotalol
# 4          Treatment failure             Unknown             propranolol
#
# [5 rows x 29 columns]

# %%
ped_data_new.isna().sum().sort_values(ascending=False)
# Out:
# fda                               351537
# ich_ema                           241452
# medicinal_product_clean               39
# patient_custom_master_age_unit         0
# patient_onsetage                       0
# patient_sex                            0
# patient_onsetageunit                   0
# nichd                                  0
# safetyreportid                         0
# lastupdate_date                        0
# mostrecent_receive_date                0
# receive_date                           0
# patient_custom_master_age              0
# congenital_anomali                     0
# death                                  0
# hospitalization                        0
# disabling                              0
# other                                  0
# serious                                0
# reporter_company                       0
# life_threatening                       0
# reporter_country                       0
# reporter_qualification                 0
# drug_characterization                  0
# drug_administration                    0
# drug_indication                        0
# medicinal_product                      0
# reaction_meddrapt                      0
# reaction_outcome                       0
# dtype: int64

# %%
ped_data_new['medicinal_product_clean'].nunique()
# Out:
# 6645

# %%
ped_data_new['medicinal_product'].nunique()
# Out:
# 16536

# %%
ped_data_new[ped_data_new['medicinal_product'].isna()]
# Out:
# Empty DataFrame
# Columns: [patient_custom_master_age, patient_custom_master_age_unit, patient_onsetage, patient_onsetageunit, patient_sex, safetyreportid, nichd, ich_ema, fda, lastupdate_date, mostrecent_receive_date, receive_date, congenital_anomali, death, disabling, hospitalization, life_threatening, other, serious, reporter_company, reporter_country, reporter_qualification, drug_administration, drug_characterization, drug_indication, medicinal_product, reaction_meddrapt, reaction_outcome, medicinal_product_clean]
# Index: []
#
# [0 rows x 29 columns]

# %%
ped_data_new[ped_data_new['medicinal_product_clean'].isna()]
# Out:
#         patient_custom_master_age patient_custom_master_age_unit  \
# 305402                    0.00274                           Year
# 305403                    0.00274                           Year
# 305404                    0.00274                           Year
# 305405                    0.00274                           Year
# 305406                    0.00274                           Year
# 305407                    0.00274                           Year
# 772955                   21.00000                           Year
# 772956                   21.00000                           Year
# 772957                   21.00000                           Year
# 772958                   21.00000                           Year
# 772959                   21.00000                           Year
# 772960                   21.00000                           Year
# 772961                   21.00000                           Year
# 772962                   21.00000                           Year
# 772963                   21.00000                           Year
#
#         patient_onsetage patient_onsetageunit patient_sex safetyreportid  \
# 305402               1.0                  Day      Female      5635836-2
# 305403               1.0                  Day      Female      5635836-2
# 305404               1.0                  Day      Female      5635836-2
# 305405               1.0                  Day      Female      5635836-2
# 305406               1.0                  Day      Female      5635836-2
# 305407               1.0                  Day      Female      5635836-2
# 772955              21.0                 Year      Female      8081148-X
# 772956              21.0                 Year      Female      8081148-X
# 772957              21.0                 Year      Female      8081148-X
# 772958              21.0                 Year      Female      8081148-X
# 772959              21.0                 Year      Female      8081148-X
# 772960              21.0                 Year      Female      8081148-X
# 772961              21.0                 Year      Female      8081148-X
# 772962              21.0                 Year      Female      8081148-X
# 772963              21.0                 Year      Female      8081148-X
#
#                    nichd               ich_ema       fda lastupdate_date  ...  \
# 305402     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 305403     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 305404     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 305405     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 305406     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 305407     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 772955  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772956  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772957  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772958  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772959  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772960  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772961  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772962  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772963  late_adolescence                   NaN       NaN      2012-06-08  ...
#
#                     reporter_company reporter_country  \
# 305402                 WAES 98061361            JAPAN
# 305403                 WAES 98061361            JAPAN
# 305404                 WAES 98061361            JAPAN
# 305405                 WAES 98061361            JAPAN
# 305406                 WAES 98061361            JAPAN
# 305407                 WAES 98061361            JAPAN
# 772955  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772956  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772957  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772958  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772959  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772960  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772961  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772962  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772963  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
#
#                      reporter_qualification  drug_administration  \
# 305402                              Unknown              Unknown
# 305403                              Unknown              Unknown
# 305404                              Unknown              Unknown
# 305405                              Unknown              Unknown
# 305406                              Unknown              Unknown
# 305407                              Unknown              Unknown
# 772955  Consumer or non-health professional              Unknown
# 772956  Consumer or non-health professional              Unknown
# 772957  Consumer or non-health professional              Unknown
# 772958  Consumer or non-health professional              Unknown
# 772959  Consumer or non-health professional              Unknown
# 772960  Consumer or non-health professional              Unknown
# 772961  Consumer or non-health professional              Unknown
# 772962  Consumer or non-health professional              Unknown
# 772963  Consumer or non-health professional              Unknown
#
#                                     drug_characterization  \
# 305402  Suspect (the drug was considered by the report...
# 305403  Suspect (the drug was considered by the report...
# 305404  Suspect (the drug was considered by the report...
# 305405  Suspect (the drug was considered by the report...
# 305406  Suspect (the drug was considered by the report...
# 305407  Suspect (the drug was considered by the report...
# 772955  Suspect (the drug was considered by the report...
# 772956  Suspect (the drug was considered by the report...
# 772957  Suspect (the drug was considered by the report...
# 772958  Suspect (the drug was considered by the report...
# 772959  Suspect (the drug was considered by the report...
# 772960  Suspect (the drug was considered by the report...
# 772961  Suspect (the drug was considered by the report...
# 772962  Suspect (the drug was considered by the report...
# 772963  Suspect (the drug was considered by the report...
#
#                             drug_indication  medicinal_product  \
# 305402             PATENT DUCTUS ARTERIOSUS                  .
# 305403             PATENT DUCTUS ARTERIOSUS                  .
# 305404             PATENT DUCTUS ARTERIOSUS                  .
# 305405             PATENT DUCTUS ARTERIOSUS                  .
# 305406             PATENT DUCTUS ARTERIOSUS                  .
# 305407             PATENT DUCTUS ARTERIOSUS                  .
# 772955  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772956  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772957  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772958  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772959  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772960  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772961  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772962  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772963  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
#
#                       reaction_meddrapt reaction_outcome  \
# 305402          VENTRICULAR TACHYCARDIA          Unknown
# 305403           ATRIOVENTRICULAR BLOCK          Unknown
# 305404              CONDUCTION DISORDER          Unknown
# 305405       BLOOD CREATININE INCREASED          Unknown
# 305406             BLOOD UREA INCREASED          Unknown
# 305407                    HYPERKALAEMIA          Unknown
# 772955                        SKIN WARM          Unknown
# 772956                     PALPITATIONS          Unknown
# 772957                             RASH          Unknown
# 772958             HEART RATE INCREASED          Unknown
# 772959                        URTICARIA          Unknown
# 772960                         HEADACHE          Unknown
# 772961                           CHILLS          Unknown
# 772962                          PYREXIA          Unknown
# 772963  ALTERED VISUAL DEPTH PERCEPTION          Unknown
#
#        medicinal_product_clean
# 305402                     NaN
# 305403                     NaN
# 305404                     NaN
# 305405                     NaN
# 305406                     NaN
# 305407                     NaN
# 772955                     NaN
# 772956                     NaN
# 772957                     NaN
# 772958                     NaN
# 772959                     NaN
# 772960                     NaN
# 772961                     NaN
# 772962                     NaN
# 772963                     NaN
#
# [15 rows x 29 columns]

# %%
ped_data = ped_data_new.copy()

# %%
ped_data[ped_data['medicinal_product_clean'].isna()]
# Out:
#         patient_custom_master_age patient_custom_master_age_unit  \
# 305402                    0.00274                           Year
# 305403                    0.00274                           Year
# 305404                    0.00274                           Year
# 305405                    0.00274                           Year
# 305406                    0.00274                           Year
# 305407                    0.00274                           Year
# 772955                   21.00000                           Year
# 772956                   21.00000                           Year
# 772957                   21.00000                           Year
# 772958                   21.00000                           Year
# 772959                   21.00000                           Year
# 772960                   21.00000                           Year
# 772961                   21.00000                           Year
# 772962                   21.00000                           Year
# 772963                   21.00000                           Year
#
#         patient_onsetage patient_onsetageunit patient_sex safetyreportid  \
# 305402               1.0                  Day      Female      5635836-2
# 305403               1.0                  Day      Female      5635836-2
# 305404               1.0                  Day      Female      5635836-2
# 305405               1.0                  Day      Female      5635836-2
# 305406               1.0                  Day      Female      5635836-2
# 305407               1.0                  Day      Female      5635836-2
# 772955              21.0                 Year      Female      8081148-X
# 772956              21.0                 Year      Female      8081148-X
# 772957              21.0                 Year      Female      8081148-X
# 772958              21.0                 Year      Female      8081148-X
# 772959              21.0                 Year      Female      8081148-X
# 772960              21.0                 Year      Female      8081148-X
# 772961              21.0                 Year      Female      8081148-X
# 772962              21.0                 Year      Female      8081148-X
# 772963              21.0                 Year      Female      8081148-X
#
#                    nichd               ich_ema       fda lastupdate_date  ...  \
# 305402     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 305403     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 305404     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 305405     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 305406     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 305407     term_neonatal  term_newborn_infants  neonates      2008-07-03  ...
# 772955  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772956  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772957  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772958  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772959  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772960  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772961  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772962  late_adolescence                   NaN       NaN      2012-06-08  ...
# 772963  late_adolescence                   NaN       NaN      2012-06-08  ...
#
#                     reporter_company reporter_country  \
# 305402                 WAES 98061361            JAPAN
# 305403                 WAES 98061361            JAPAN
# 305404                 WAES 98061361            JAPAN
# 305405                 WAES 98061361            JAPAN
# 305406                 WAES 98061361            JAPAN
# 305407                 WAES 98061361            JAPAN
# 772955  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772956  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772957  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772958  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772959  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772960  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772961  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772962  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
# 772963  US-GLAXOSMITHKLINE-A0962933A    UNITED STATES
#
#                      reporter_qualification  drug_administration  \
# 305402                              Unknown              Unknown
# 305403                              Unknown              Unknown
# 305404                              Unknown              Unknown
# 305405                              Unknown              Unknown
# 305406                              Unknown              Unknown
# 305407                              Unknown              Unknown
# 772955  Consumer or non-health professional              Unknown
# 772956  Consumer or non-health professional              Unknown
# 772957  Consumer or non-health professional              Unknown
# 772958  Consumer or non-health professional              Unknown
# 772959  Consumer or non-health professional              Unknown
# 772960  Consumer or non-health professional              Unknown
# 772961  Consumer or non-health professional              Unknown
# 772962  Consumer or non-health professional              Unknown
# 772963  Consumer or non-health professional              Unknown
#
#                                     drug_characterization  \
# 305402  Suspect (the drug was considered by the report...
# 305403  Suspect (the drug was considered by the report...
# 305404  Suspect (the drug was considered by the report...
# 305405  Suspect (the drug was considered by the report...
# 305406  Suspect (the drug was considered by the report...
# 305407  Suspect (the drug was considered by the report...
# 772955  Suspect (the drug was considered by the report...
# 772956  Suspect (the drug was considered by the report...
# 772957  Suspect (the drug was considered by the report...
# 772958  Suspect (the drug was considered by the report...
# 772959  Suspect (the drug was considered by the report...
# 772960  Suspect (the drug was considered by the report...
# 772961  Suspect (the drug was considered by the report...
# 772962  Suspect (the drug was considered by the report...
# 772963  Suspect (the drug was considered by the report...
#
#                             drug_indication  medicinal_product  \
# 305402             PATENT DUCTUS ARTERIOSUS                  .
# 305403             PATENT DUCTUS ARTERIOSUS                  .
# 305404             PATENT DUCTUS ARTERIOSUS                  .
# 305405             PATENT DUCTUS ARTERIOSUS                  .
# 305406             PATENT DUCTUS ARTERIOSUS                  .
# 305407             PATENT DUCTUS ARTERIOSUS                  .
# 772955  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772956  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772957  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772958  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772959  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772960  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772961  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772962  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
# 772963  PRODUCT USED FOR UNKNOWN INDICATION          INJECTION
#
#                       reaction_meddrapt reaction_outcome  \
# 305402          VENTRICULAR TACHYCARDIA          Unknown
# 305403           ATRIOVENTRICULAR BLOCK          Unknown
# 305404              CONDUCTION DISORDER          Unknown
# 305405       BLOOD CREATININE INCREASED          Unknown
# 305406             BLOOD UREA INCREASED          Unknown
# 305407                    HYPERKALAEMIA          Unknown
# 772955                        SKIN WARM          Unknown
# 772956                     PALPITATIONS          Unknown
# 772957                             RASH          Unknown
# 772958             HEART RATE INCREASED          Unknown
# 772959                        URTICARIA          Unknown
# 772960                         HEADACHE          Unknown
# 772961                           CHILLS          Unknown
# 772962                          PYREXIA          Unknown
# 772963  ALTERED VISUAL DEPTH PERCEPTION          Unknown
#
#        medicinal_product_clean
# 305402                     NaN
# 305403                     NaN
# 305404                     NaN
# 305405                     NaN
# 305406                     NaN
# 305407                     NaN
# 772955                     NaN
# 772956                     NaN
# 772957                     NaN
# 772958                     NaN
# 772959                     NaN
# 772960                     NaN
# 772961                     NaN
# 772962                     NaN
# 772963                     NaN
#
# [15 rows x 29 columns]

# %%
ped_data= ped_data.dropna(subset=['medicinal_product_clean'])

# %%
ped_data[ped_data['medicinal_product_clean'].isna()]
# Out:
# Empty DataFrame
# Columns: [patient_custom_master_age, patient_custom_master_age_unit, patient_onsetage, patient_onsetageunit, patient_sex, safetyreportid, nichd, ich_ema, fda, lastupdate_date, mostrecent_receive_date, receive_date, congenital_anomali, death, disabling, hospitalization, life_threatening, other, serious, reporter_company, reporter_country, reporter_qualification, drug_administration, drug_characterization, drug_indication, medicinal_product, reaction_meddrapt, reaction_outcome, medicinal_product_clean]
# Index: []
#
# [0 rows x 29 columns]

# %%
ped_data['medicinal_product_clean'].nunique()
# Out:
# 6590

# %% [markdown]
# ## Drug V2

# %%
# clean_drug_v1[clean_drug_v1['medicinal_product'] == 'HEMO-8R']

# %%
drug_v2 = pd.read_csv('../../data/v2/drug_clean_search_v2.csv')

# %%
drug_v2
# Out:
#                                    medicinal_product medicinal_product_clean
# 0                                         FLECAINIDE              flecainide
# 1                                        PROPRANOLOL             propranolol
# 2                                            ESMOLOL                 esmolol
# 3                              SOTALOL HYDROCHLORIDE                 sotalol
# 4                         PROCAINAMIDE HYDROCHLORIDE            procainamide
# ...                                              ...                     ...
# 14334                                       ORAMORPH                morphine
# 14335                          ESCITALOPRAM OXALATE.            escitalopram
# 14336                                          HALOG           betamethasone
# 14337  BACTROBAN                          /00753901/               mupirocin
# 14338  CLODERM                            /00212501/              clobetasol
#
# [14339 rows x 2 columns]

# %%
drug_v2.isna().sum()
# Out:
# medicinal_product          0
# medicinal_product_clean    0
# dtype: int64

# %%
rows_with_comma_clean = drug_v2[drug_v2['medicinal_product_clean'].str.contains(',', na=False)]
print(f"row: {len(rows_with_comma_clean)}")
display(rows_with_comma_clean)
# Out:
# row: 1860
#                                   medicinal_product  \
# 14                          Irinotecan;Temozolomide
# 23                                      M-M-RVAXPRO
# 26                      PIPERACILLIN AND TAZOBACTAM
# 83                                         TRIKAFTA
# 102                          NIRMATRELVIR\RITONAVIR
# ...                                             ...
# 14308                          ROBITUSSIN DM PFIZER
# 14312                    AMFETAMINE W/DEXAMFETAMINE
# 14321  AMOXICILLIN TRIHYDRATE,POTASSIUM CLAVULANATE
# 14326                                 ROBITUSSIN-DM
# 14332        AMOXICILLIN TRIHYDRATE/CLAVULANIC ACID
#
#                   medicinal_product_clean
# 14                irinotecan,temozolomide
# 23        measles, mumps, rubella vaccine
# 26                piperacillin,tazobactam
# 83     elexacaftor, tezacaftor, ivacaftor
# 102                nirmatrelvir,ritonavir
# ...                                   ...
# 14308       dextromethorphan, guaifenesin
# 14312          amphetamine,dexamphetamine
# 14321   amoxicillin,potassium clavulanate
# 14326        dextromethorphan,guaifenesin
# 14332         amoxicillin,clavulanic acid
#
# [1860 rows x 2 columns]

# %%
unique_drug_v2 = drug_v2['medicinal_product'].nunique()
unique_clean_drug_v2 = drug_v2['medicinal_product_clean'].nunique()

print(f'Unique Raw drug V2: {unique_drug_v2:,}')
print(f'Unique Clean drug V2: {unique_clean_drug_v2:,}')
# Out:
# Unique Raw drug V2: 14,339
# Unique Clean drug V2: 3,969

# %%
drug_v2[drug_v2['medicinal_product_clean'] == ',']
# Out:
#            medicinal_product medicinal_product_clean
# 12116  GRASS MIX (KORT + SV)                       ,
# 12117             BIRCH TREE                       ,
# 12118               OAK TREE                       ,
# 12119          SHORT RAGWEED                       ,
# 14123              ERGY-EPUR                       ,
# 14125       FLUOROQUINOLONES                       ,

# %%
drug_v2[drug_v2['medicinal_product_clean'] == '.']
# Out:
# Empty DataFrame
# Columns: [medicinal_product, medicinal_product_clean]
# Index: []

# %% [markdown]
# ### clean drug v2

# %%
clean_drug_v2 = pd.read_csv('../../data/v2/clean_drug_v2.csv')

# %%
clean_drug_v2
# Out:
#        safetyreportid      medicinal_product medicinal_product_clean
# 0            25129349             FLECAINIDE              flecainide
# 1            25129349            PROPRANOLOL             propranolol
# 2            25129367                ESMOLOL                 esmolol
# 3            25129367  SOTALOL HYDROCHLORIDE                 sotalol
# 4            25129367            PROPRANOLOL             propranolol
# ...               ...                    ...                     ...
# 881391        8651696                EXTAVIA      interferon beta-1b
# 881392        8651696                EXTAVIA      interferon beta-1b
# 881393        8651696                EXTAVIA      interferon beta-1b
# 881394        8651812            ANTIBIOTICS             antibiotics
# 881395        8651812               REMICADE              infliximab
#
# [881396 rows x 3 columns]

# %%
rows_with_comma_clean = clean_drug_v2[clean_drug_v2['medicinal_product_clean'].str.contains(',', na=False)]
print(f"row: {len(rows_with_comma_clean)}")
display(rows_with_comma_clean)
# Out:
# row: 77729
#        safetyreportid            medicinal_product  \
# 37           25129461      Irinotecan;Temozolomide
# 69           25129620                  M-M-RVAXPRO
# 75           25129666  PIPERACILLIN AND TAZOBACTAM
# 76           25129666  PIPERACILLIN AND TAZOBACTAM
# 392          25130808                     TRIKAFTA
# ...               ...                          ...
# 881249        8649832                          YAZ
# 881250        8649832                          YAZ
# 881251        8649832                          YAZ
# 881252        8649832                          YAZ
# 881253        8649832                          YAZ
#
#                    medicinal_product_clean
# 37                 irinotecan,temozolomide
# 69         measles, mumps, rubella vaccine
# 75                 piperacillin,tazobactam
# 76                 piperacillin,tazobactam
# 392     elexacaftor, tezacaftor, ivacaftor
# ...                                    ...
# 881249     drospirenone, ethinyl estradiol
# 881250     drospirenone, ethinyl estradiol
# 881251     drospirenone, ethinyl estradiol
# 881252     drospirenone, ethinyl estradiol
# 881253     drospirenone, ethinyl estradiol
#
# [77729 rows x 3 columns]

# %%
clean_drug_v2.isna().sum()
# Out:
# safetyreportid                 0
# medicinal_product              0
# medicinal_product_clean    25632
# dtype: int64

# %%
clean_drug_v2[clean_drug_v2['medicinal_product_clean'].isna()]
# Out:
#        safetyreportid       medicinal_product medicinal_product_clean
# 423          25130961                 HEMO-8R                     NaN
# 424          25130961                 HEMO-8R                     NaN
# 425          25130961                 HEMO-8R                     NaN
# 632          25132108  UNSPECIFIED INGREDIENT                     NaN
# 633          25132108  UNSPECIFIED INGREDIENT                     NaN
# ...               ...                     ...                     ...
# 881369        8650139                CLARAVIS                     NaN
# 881370        8650139                CLARAVIS                     NaN
# 881371        8650139                CLARAVIS                     NaN
# 881372        8650139                CLARAVIS                     NaN
# 881373        8650139                CLARAVIS                     NaN
#
# [25632 rows x 3 columns]

# %%
clean_drug_v2[clean_drug_v2['medicinal_product'] == '.']
# Out:
#        safetyreportid medicinal_product medicinal_product_clean
# 305402      5635836-2                 .                     NaN
# 305403      5635836-2                 .                     NaN
# 305404      5635836-2                 .                     NaN
# 305405      5635836-2                 .                     NaN
# 305406      5635836-2                 .                     NaN
# 305407      5635836-2                 .                     NaN

# %% [markdown]
# ### ped v2

# %%
ped_data_new_v2 = pd.read_csv('../../data/v2/ped_data_new_v2.csv.gz', compression='gzip')

# %%
ped_data_new_v2.head()
# Out:
#    patient_custom_master_age patient_custom_master_age_unit  patient_onsetage  \
# 0                   0.500000                           Year               6.0
# 1                   0.500000                           Year               6.0
# 2                   0.013699                           Year               5.0
# 3                   0.013699                           Year               5.0
# 4                   0.013699                           Year               5.0
#
#   patient_onsetageunit patient_sex safetyreportid          nichd  \
# 0                Month      Female       25129349        infancy
# 1                Month      Female       25129349        infancy
# 2                  Day     Unknown       25129367  term_neonatal
# 3                  Day     Unknown       25129367  term_neonatal
# 4                  Day     Unknown       25129367  term_neonatal
#
#                 ich_ema       fda lastupdate_date  ...  \
# 0  infants_and_toddlers   infants      2025-04-09  ...
# 1  infants_and_toddlers   infants      2025-04-09  ...
# 2  term_newborn_infants  neonates      2025-04-09  ...
# 3  term_newborn_infants  neonates      2025-04-09  ...
# 4  term_newborn_infants  neonates      2025-04-09  ...
#
#                    reporter_company reporter_country  \
# 0                  ES-AEMPS-1647130               ES
# 1                  ES-AEMPS-1647130               ES
# 2  US-AUROBINDO-AUR-APL-2025-015649               US
# 3  US-AUROBINDO-AUR-APL-2025-015649               US
# 4  US-AUROBINDO-AUR-APL-2025-015649               US
#
#       reporter_qualification  drug_administration  \
# 0                  Physician                 Oral
# 1                  Physician                 Oral
# 2  Other health professional              Unknown
# 3  Other health professional              Unknown
# 4  Other health professional              Unknown
#
#                                drug_characterization  \
# 0  Suspect (the drug was considered by the report...
# 1  Concomitant (the drug was reported as being ta...
# 2  Suspect (the drug was considered by the report...
# 3  Suspect (the drug was considered by the report...
# 4  Suspect (the drug was considered by the report...
#
#                 drug_indication      medicinal_product  \
# 0  Supraventricular tachycardia             FLECAINIDE
# 1  Supraventricular tachycardia            PROPRANOLOL
# 2  Supraventricular tachycardia                ESMOLOL
# 3  Supraventricular tachycardia  SOTALOL HYDROCHLORIDE
# 4  Supraventricular tachycardia            PROPRANOLOL
#
#            reaction_meddrapt    reaction_outcome medicinal_product_clean
# 0  Bundle branch block right  Recovered/resolved              flecainide
# 1  Bundle branch block right  Recovered/resolved             propranolol
# 2          Treatment failure             Unknown                 esmolol
# 3          Treatment failure             Unknown                 sotalol
# 4          Treatment failure             Unknown             propranolol
#
# [5 rows x 29 columns]

# %%
ped_data_new_v2.isna().sum().sort_values(ascending=False)
# Out:
# fda                               351537
# ich_ema                           241452
# medicinal_product_clean            25632
# patient_custom_master_age_unit         0
# patient_onsetage                       0
# patient_sex                            0
# patient_onsetageunit                   0
# nichd                                  0
# safetyreportid                         0
# lastupdate_date                        0
# mostrecent_receive_date                0
# receive_date                           0
# patient_custom_master_age              0
# congenital_anomali                     0
# death                                  0
# hospitalization                        0
# disabling                              0
# other                                  0
# serious                                0
# reporter_company                       0
# life_threatening                       0
# reporter_country                       0
# reporter_qualification                 0
# drug_characterization                  0
# drug_administration                    0
# drug_indication                        0
# medicinal_product                      0
# reaction_meddrapt                      0
# reaction_outcome                       0
# dtype: int64

# %%
ped_data_new_v2 = ped_data_new_v2.dropna(subset=['medicinal_product_clean'])

# %%
ped_data_new_v2.isna().sum().sort_values(ascending=False)
# Out:
# fda                               342628
# ich_ema                           235173
# patient_onsetage                       0
# patient_custom_master_age_unit         0
# patient_custom_master_age              0
# patient_sex                            0
# patient_onsetageunit                   0
# nichd                                  0
# safetyreportid                         0
# lastupdate_date                        0
# mostrecent_receive_date                0
# receive_date                           0
# congenital_anomali                     0
# death                                  0
# disabling                              0
# hospitalization                        0
# life_threatening                       0
# other                                  0
# serious                                0
# reporter_company                       0
# reporter_country                       0
# reporter_qualification                 0
# drug_administration                    0
# drug_characterization                  0
# drug_indication                        0
# medicinal_product                      0
# reaction_meddrapt                      0
# reaction_outcome                       0
# medicinal_product_clean                0
# dtype: int64

# %%
ped_data_new_v2.shape
# Out:
# (855764, 29)

# %%
ped_data_new_v2.to_csv('../../data/v2/ped_data_new_v2.csv', index=False)

# %%
ped_data_new_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 855764 entries, 0 to 881395
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   patient_custom_master_age       855764 non-null  float64
#  1   patient_custom_master_age_unit  855764 non-null  object
#  2   patient_onsetage                855764 non-null  float64
#  3   patient_onsetageunit            855764 non-null  object
#  4   patient_sex                     855764 non-null  object
#  5   safetyreportid                  855764 non-null  object
#  6   nichd                           855764 non-null  object
#  7   ich_ema                         620591 non-null  object
#  8   fda                             513136 non-null  object
#  9   lastupdate_date                 855764 non-null  object
#  10  mostrecent_receive_date         855764 non-null  object
#  11  receive_date                    855764 non-null  object
#  12  congenital_anomali              855764 non-null  int64
#  13  death                           855764 non-null  int64
#  14  disabling                       855764 non-null  int64
#  15  hospitalization                 855764 non-null  int64
#  16  life_threatening                855764 non-null  int64
#  17  other                           855764 non-null  int64
#  18  serious                         855764 non-null  object
#  19  reporter_company                855764 non-null  object
#  20  reporter_country                855764 non-null  object
#  21  reporter_qualification          855764 non-null  object
#  22  drug_administration             855764 non-null  object
#  23  drug_characterization           855764 non-null  object
#  24  drug_indication                 855764 non-null  object
#  25  medicinal_product               855764 non-null  object
#  26  reaction_meddrapt               855764 non-null  object
#  27  reaction_outcome                855764 non-null  object
#  28  medicinal_product_clean         855764 non-null  object
# dtypes: float64(2), int64(6), object(21)
# memory usage: 195.9+ MB

# %%
test = pd.read_csv('../../data/v2/drug_search_with_rxcui.csv')

# %%
test.isna().sum()
# Out:
# medicinal_product_clean        0
# rxcui                      13828
# flag                           0
# dtype: int64

# %%
test[test['rxcui'].isna()]
# Out:
#                                  medicinal_product_clean rxcui  flag
# 0                                                      ,   NaN     0
# 1                                                      ,   NaN     0
# 2                                                      ,   NaN     0
# 3                                                      ,   NaN     0
# 4                                                      ,   NaN     0
# ...                                                  ...   ...   ...
# 14312                  folic acid,iron,minerals,vitamins   NaN     0
# 14313                insulin, regular, insulin, isophane   NaN     0
# 14315  eucalyptus oil, turpentine, cedar leaf oil, ce...   NaN     0
# 14333  diphtheria toxoid, tetanus toxoid, pertussis t...   NaN     0
# 14336  betamethasone, dexchlorpheniramine, betamethas...   NaN     0
#
# [13828 rows x 3 columns]

# %%
test[test['flag'] == 1]
# Out:
#                                  medicinal_product_clean  \
# 7                                     sulfamethopyrazine
# 8                                              sulpiride
# 9                                             furosemide
# 10                                       chloramphenicol
# 11                                            cetirizine
# ...                                                  ...
# 14332  acetaminophen, phenylephrine, guaifenesin, dex...
# 14334  paracetamol,dextromethorphan,doxylamine,pseudo...
# 14335  cobalamin, pyridoxine, riboflavin, thiamine, a...
# 14337  vitamin a, vitamin c, vitamin d, vitamin e, vi...
# 14338  vitamin a, vitamin b1, vitamin b2, vitamin b3,...
#
#                                                    rxcui  flag
# 7                                                  10175     1
# 8                                                  10239     1
# 9                                                   4603     1
# 10                                                  2348     1
# 11                                                 20610     1
# ...                                                  ...   ...
# 14332                                               3289     1
# 14334                                               8896     1
# 14335                                         10454,1151     1
# 14337           11248,11256,1895,42954,4511,684879,90176     1
# 14338  11248,11253,11256,1151,1588,42954,4511,684879,...     1
#
# [511 rows x 3 columns]

# %%
drug_v2[drug_v2['medicinal_product_clean'].str.contains('vitamin a, vitamin c, vitamin d, vitamin e,', na=False)]
# Out:
#       medicinal_product                            medicinal_product_clean
# 3165  PRENATAL VITAMINS  vitamin a, vitamin c, vitamin d, vitamin e, vi...

# %%
# สรุปการค้นหา comma ในทุกคอลัมน์
print("สรุปการค้นหา comma ในแต่ละคอลัมน์:")
print("="*50)

for col in clean_drug_v2.columns:
    if clean_drug_v2[col].dtype == 'object':  # ตรวจสอบเฉพาะคอลัมน์ที่เป็น string
        comma_count = clean_drug_v2[col].str.contains(',', na=False).sum()
        print(f"{col}: {comma_count:,} แถว")

print("\n" + "="*50)
print("แถวที่มี comma ในคอลัมน์ใด ๆ:")
# สร้าง mask สำหรับแถวที่มี comma ในคอลัมน์ใด ๆ
has_comma_mask = False
for col in clean_drug_v2.columns:
    if clean_drug_v2[col].dtype == 'object':
        has_comma_mask |= clean_drug_v2[col].str.contains(',', na=False)

rows_with_any_comma = clean_drug_v2[has_comma_mask]
print(f"จำนวนแถวที่มี comma ในคอลัมน์ใด ๆ: {len(rows_with_any_comma):,}")
# Out:
# สรุปการค้นหา comma ในแต่ละคอลัมน์:
# ==================================================
# safetyreportid: 0 แถว
# medicinal_product: 7,537 แถว
# medicinal_product_clean: 77,729 แถว
#
# ==================================================
# แถวที่มี comma ในคอลัมน์ใด ๆ:
# จำนวนแถวที่มี comma ในคอลัมน์ใด ๆ: 82,567

# %%
# แสดงตัวอย่างแถวที่มี comma พร้อมรายละเอียด
print("ตัวอย่างแถวที่มี comma (แสดง 20 แถวแรก):")
print("="*80)
display(rows_with_any_comma.head(20))

print("\n" + "="*80)
print("ค้นหาเฉพาะแถวที่มี comma ในชื่อยา (medicinal_product_clean):")
if len(rows_with_comma_clean) > 0:
    print(f"พบ {len(rows_with_comma_clean)} แถว")
    print("\nรายการชื่อยาที่มี comma:")
    unique_drugs_with_comma = rows_with_comma_clean['medicinal_product_clean'].unique()
    for i, drug in enumerate(unique_drugs_with_comma[:30], 1):  # แสดง 30 รายการแรก
        print(f"{i:2d}. {drug}")
    
    if len(unique_drugs_with_comma) > 30:
        print(f"... และอีก {len(unique_drugs_with_comma) - 30} รายการ")
else:
    print("ไม่พบแถวที่มี comma ในคอลัมน์ medicinal_product_clean")
# Out:
# ตัวอย่างแถวที่มี comma (แสดง 20 แถวแรก):
# ================================================================================
#     safetyreportid                                  medicinal_product  \
# 37        25129461                            Irinotecan;Temozolomide
# 69        25129620                                        M-M-RVAXPRO
# 75        25129666                        PIPERACILLIN AND TAZOBACTAM
# 76        25129666                        PIPERACILLIN AND TAZOBACTAM
# 392       25130808                                           TRIKAFTA
# 393       25130808                                           TRIKAFTA
# 394       25130808                                           TRIKAFTA
# 460       25131328                             NIRMATRELVIR\RITONAVIR
# 461       25131328                             NIRMATRELVIR\RITONAVIR
# 558       25131730                                           M-M-R II
# 559       25131730                                           M-M-R II
# 566       25131755  ANTICOAGULANT CITRATE DEXTROSE SOLUTION (ACD) NOS
# 567       25131755  ANTICOAGULANT CITRATE DEXTROSE SOLUTION (ACD) NOS
# 568       25131755  ANTICOAGULANT CITRATE DEXTROSE SOLUTION (ACD) NOS
# 569       25131755  ANTICOAGULANT CITRATE DEXTROSE SOLUTION (ACD) NOS
# 570       25131755  ANTICOAGULANT CITRATE DEXTROSE SOLUTION (ACD) NOS
# 931       25133414                                  ALBUTEROL SULFATE
# 932       25133414                                  ALBUTEROL SULFATE
# 933       25133414                                  ALBUTEROL SULFATE
# 934       25133414                                   AZTREONAM LYSINE
#
#                                medicinal_product_clean
# 37                             irinotecan,temozolomide
# 69                     measles, mumps, rubella vaccine
# 75                             piperacillin,tazobactam
# 76                             piperacillin,tazobactam
# 392                 elexacaftor, tezacaftor, ivacaftor
# 393                 elexacaftor, tezacaftor, ivacaftor
# 394                 elexacaftor, tezacaftor, ivacaftor
# 460                             nirmatrelvir,ritonavir
# 461                             nirmatrelvir,ritonavir
# 558  measles virus vaccine, mumps virus vaccine, ru...
# 559  measles virus vaccine, mumps virus vaccine, ru...
# 566    anticoagulant citrate dextrose solution a, c, d
# 567    anticoagulant citrate dextrose solution a, c, d
# 568    anticoagulant citrate dextrose solution a, c, d
# 569    anticoagulant citrate dextrose solution a, c, d
# 570    anticoagulant citrate dextrose solution a, c, d
# 931                                 albuterol, sulfate
# 932                                 albuterol, sulfate
# 933                                 albuterol, sulfate
# 934                                  aztreonam, lysine
# ================================================================================
# ค้นหาเฉพาะแถวที่มี comma ในชื่อยา (medicinal_product_clean):
# พบ 1860 แถว
#
# รายการชื่อยาที่มี comma:
#  1. irinotecan,temozolomide
#  2. measles, mumps, rubella vaccine
#  3. piperacillin,tazobactam
#  4. elexacaftor, tezacaftor, ivacaftor
#  5. nirmatrelvir,ritonavir
#  6. measles virus vaccine, mumps virus vaccine, rubella virus vaccine
#  7. anticoagulant citrate dextrose solution a, c, d
#  8. albuterol, sulfate
#  9. aztreonam, lysine
# 10. chlorpheniramine,dextromethorphan,phenylephrine
# 11. amoxicillin,clarithromycin,omeprazole
# 12. sulfamethoxazole,trimethoprim
# 13. sacubitril, valsartan
# 14. articaine, epinephrine
# 15. acetaminophen,dichloralphenazone,isometheptene
# 16. budesonide, formoterol
# 17. ethinyl estradiol, levonorgestrel
# 18. bictegravir, emtricitabine, tenofovir alafenamide
# 19. sulfamethoxazole, trimethoprim
# 20. lidocaine, prilocaine
# 21. lamivudine, zidovudine
# 22. acetaminophen,codeine
# 23. ethinyl estradiol, norgestimate
# 24. metronidazole,spiramycin
# 25. acetaminophen, paracetamol
# 26. amphetamine, sulfate
# 27. insulin, isophane
# 28. ethinylestradiol, norelgestromin
# 29. amphetamine, dextroamphetamine
# 30. ipratropium, albuterol
# ... และอีก 876 รายการ
